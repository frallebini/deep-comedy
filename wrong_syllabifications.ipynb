# %% [markdown]
# In the following, we display the correct and predicted syllabification of the verses for which those two do not coincide and compute the percentage of correctly syllabified verses.

# %% [markdown]
# # Setup

# %%
from google.colab import drive

drive.mount('/content/drive/')
# %cd '/content/drive/My Drive/Deep Comedy/src'
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/Deep Comedy/src

# %%
import logging
from IPython.utils import io

from transformer import Transformer
from syllabification import syllabify, get_tokenizers

# %%
logging.getLogger('tensorflow').setLevel(logging.ERROR)  # suppress warnings

# %%
# %%capture
def cd(path):
    # %cd path

# %%
train_verses_nosyll = []
val_verses_nosyll = []
test_verses_nosyll = []

train_verses_syll = []
val_verses_syll = []
test_verses_syll = []

verse_info = {
    'train_nosyll': {
        'fname': 'training_set_nosyll.txt',
        'verses': train_verses_nosyll
    },
    'val_nosyll': {
        'fname': 'validation_set_nosyll.txt',
        'verses': val_verses_nosyll
    },
    'test_nosyll': {
        'fname': 'test_set_nosyll.txt',
        'verses': test_verses_nosyll
    },
    'train_ground': {
        'fname': 'training_set_ground_truth.txt',
        'verses': train_verses_syll
    },
    'val_ground': {
        'fname': 'validation_set_ground_truth.txt',
        'verses': val_verses_syll
    },
    'test_ground': {
        'fname': 'test_set_ground_truth.txt',
        'verses': test_verses_syll
    }
}

# %cd '/content/drive/My Drive/Deep Comedy/syllabifications'

for k in verse_info.keys():
    with open(verse_info[k]['fname']) as f:
        for verse in f:
            verse = verse.rstrip('\n')
            verse_info[k]['verses'].append(f'<{verse}>')
# Out:
# /content/drive/My Drive/Deep Comedy/syllabifications

# %%
syllabifier = Transformer(
    num_layers=2,
    d_model=128,
    num_heads=2,
    dff=32,
    input_vocab_size=80+1,
    target_vocab_size=81+1,
    pe_input=1000,
    pe_target=1000,
    rate=0.1)

# %%
# %cd '/content/drive/My Drive/Deep Comedy'

syllabifier.load_weights('./syllabification_weights/')
# Out:
# /content/drive/My Drive/Deep Comedy

# %%
tokenizer_nosyll, tokenizer_syll = get_tokenizers()
# Out:
# Downloading data from https://raw.githubusercontent.com/asperti/Dante/main/inferno.txt
# 204800/203103 [==============================] - 0s 0us/step
# Downloading data from https://raw.githubusercontent.com/asperti/Dante/main/purgatorio.txt
# 204800/202955 [==============================] - 0s 0us/step
# Downloading data from https://raw.githubusercontent.com/asperti/Dante/main/paradiso.txt
# 204800/199196 [==============================] - 0s 0us/step
# Downloading data from https://raw.githubusercontent.com/asperti/Dante/main/inferno_syllnew.txt
# 327680/319986 [==============================] - 0s 0us/step
# Downloading data from https://raw.githubusercontent.com/asperti/Dante/main/purgatorio_syllnew.txt
# 327680/321559 [==============================] - 0s 0us/step
# Downloading data from https://raw.githubusercontent.com/asperti/Dante/main/paradiso_syllnew.txt
# 319488/314474 [==============================] - 0s 0us/step

# %% [markdown]
# # Dataset Syllabification
#
# In order to be able to retrieve the already computed syllabifications in case of crashes/disconnections, we first write them down in a file.

# %%
def write_predictions(verses_nosyll, verses_syll, fname):
    with open(fname, 'w') as f:
        for i, (verse, ground_truth) in enumerate(zip(verses_nosyll, verses_syll)):
            with io.capture_output() as captured:
                cd('/content/drive/My Drive/Deep Comedy')
            print(f'{i}/{len(verses_syll)}')

            prediction = syllabify(verse, syllabifier, tokenizer_nosyll, tokenizer_syll)

            with io.capture_output() as captured:
                cd('/content/drive/My Drive/Deep Comedy/syllabifications')
            f.write(f"{prediction[0].replace('<','').replace('>','')}\n")

# %%
def store_predictions(fname):
    with io.capture_output() as captured:
        cd('/content/drive/My Drive/Deep Comedy/syllabifications')
    predictions = []
    with open(fname) as f:
        for verse in f:
            predictions.append(verse.rstrip('\n'))
    return predictions

# %%
def print_mistakes(verses_nosyll, predictions, ground_truths):
    mistakes = []
    for verse, prediction, ground_truth in zip(verses_nosyll, predictions, ground_truths):
        ground_truth = ground_truth.replace('<','').replace('>','')
        if prediction != ground_truth:
            print(f'Syllabifier input:       {verse}'.replace('<','').rstrip('>'))
            print(f'Syllabifier output:      {prediction}'.replace('<','').rstrip('>'))
            print(f'Correct syllabification: {ground_truth}'.replace('<','').rstrip('>'))
            print()
            mistakes.append((ground_truth, prediction))
    return mistakes

# %%
def print_ratio(verses_nosyll, mistakes):
    l = len(verses_nosyll)
    acc = (l-len(mistakes))/l
    print(f'Number of correctly syllabified verses: {l-len(mistakes)}/{l} ({acc*100:.1f}%)')

# %%
# %cd '/content/drive/My Drive/Deep Comedy/syllabifications'
# Out:
# /content/drive/My Drive/Deep Comedy/syllabifications

# %% [markdown]
# ## Test Set

# %%
#write_predictions(test_verses_nosyll, test_verses_syll, 'test_set_prediction.txt')

# %%
test_set_predictions = store_predictions('test_set_prediction.txt')

# %%
test_set_mistakes = print_mistakes(test_verses_nosyll, test_set_predictions, test_verses_syll)
# Out:
# Syllabifier input:       io dico d’Aristotile e di Plato
# Syllabifier output:      |io |di|co |d’ A|ri|sto|ti|le |di |Pla|to
# Correct syllabification: |io |di|co |d’ A|ri|sto|ti|le e |di |Pla|to
#
# Syllabifier input:       E non er’ anco del mio petto essausto
# Syllabifier output:      |E |non |e|r’ an|co |del |mio |pet|to es|sa|u|sto
# Correct syllabification: |E |non |e|r’ an|co |del |mio |pet|to es|sau|sto
#
# Syllabifier input:       ficcava ïo sì come far suole
# Syllabifier output:      |fic|ca|va ï|o |sì |co|me |far |suo|le
# Correct syllabification: |fic|ca|va |ï|o |sì |co|me |far |suo|le
#
# Syllabifier input:       vedi oggimai quant’ esser dee quel tutto
# Syllabifier output:      |ve|di og|gi|mai |quan|t’ es|ser |de |quel |tut|to
# Correct syllabification: |ve|di og|gi|mai |quan|t’ es|ser |dee |quel |tut|to
#
# Syllabifier input:       Io avea già il mio viso nel suo fitto;
# Syllabifier output:      |Io |a|vea |già |il |mio |vi|so |nel |suo |fit|to;
# Correct syllabification: |Io |a|vea |già il |mio |vi|so |nel |suo |fit|to;
#
# Syllabifier input:       più nel suo amor, più mi si fé nemica.
# Syllabifier output:      |più |nel |suo |a|mor, |più |mi |si |fé |ne|mi|ca.
# Correct syllabification: |più |nel |suo a|mor, |più |mi |si |fé |ne|mi|ca.
#
# Syllabifier input:       sovenha vos a temps de ma dolor!».
# Syllabifier output:      |so|ve|nha |vos |a |tem|ps |de |ma |do|lor!».
# Correct syllabification: |so|ve|nha |vos |a |temps |de |ma |do|lor!».
#
# Syllabifier input:       Curïo, ch’a dir fu così ardito!
# Syllabifier output:      |Cu|rï|o, |ch’ a |dir |fu |co|sì ar|di|to!
# Correct syllabification: |Cu|rï|o, |ch’ a |dir |fu |co|sì |ar|di|to!
#
# Syllabifier input:       si vede di giustizia orribil arte.
# Syllabifier output:      |si |ve|de |di |giu|sti|zia or|ri|bil ar|te.
# Correct syllabification: |si |ve|de |di |giu|sti|zia or|ri|bil |ar|te.
#
# Syllabifier input:       parlerei a quei due che ’nsieme vanno,
# Syllabifier output:      |par|le|rei a |quei |due |che ’n|sie|me |van|no,
# Correct syllabification: |par|le|rei |a |quei |due |che ’n|sie|me |van|no,
#
# Syllabifier input:       Caina attende chi a vita ci spense».
# Syllabifier output:      |Ca|i|na at|ten|de |chi |a |vi|ta |ci |spen|se».
# Correct syllabification: |Ca|i|na at|ten|de |chi a |vi|ta |ci |spen|se».
#
# Syllabifier input:       fu il cantor de lo Spirito Santo,
# Syllabifier output:      |fu il |can|tor |de |lo |Spi|ri|to |San|to,
# Correct syllabification: |fu |il |can|tor |de |lo |Spi|ri|to |San|to,
#
# Syllabifier input:       Grandine grossa, acqua tinta e neve
# Syllabifier output:      |Gran|di|ne |gros|sa, ac|qua |tin|ta e |ne|ve
# Correct syllabification: |Gran|di|ne |gros|sa, |ac|qua |tin|ta e |ne|ve
#
# Syllabifier input:       Poco portäi in là volta la testa,
# Syllabifier output:      |Po|co |por|tä |in |là |vol|ta |la |te|sta,
# Correct syllabification: |Po|co |por|tä|i in |là |vol|ta |la |te|sta,
#
# Syllabifier input:       Quivi è la sapïenza e la possanza
# Syllabifier output:      |Qui|vi è |la |sa|pï|pan|za e |la |pos|san|za
# Correct syllabification: |Qui|vi è |la |sa|pï|en|za e |la |pos|san|za
#
# Syllabifier input:       L’acqua era buia assai più che persa;
# Syllabifier output:      |L’ ac|qua e|ra |bu|ia as|sai |più |che |per|sa;
# Correct syllabification: |L’ ac|qua e|ra |bu|ia |as|sai |più |che |per|sa;
#
# Syllabifier input:       cominciò, ‘gloria!’, tutto ’l paradiso,
# Syllabifier output:      |co|min|ciò, |‘lo|ria!’, |tut|to ’l |pa|ra|ra|di|so,
# Correct syllabification: |co|min|ciò, |‘glo|ria! ’, |tut|to ’l |pa|ra|di|so,
#
# Syllabifier input:       cominciò ’l Mantoan che ci avea vòlti,
# Syllabifier output:      |co|min|ciò ’l |Man|toan |che |ci a|vea |vòl|ti,
# Correct syllabification: |co|min|ciò ’l |Man|to|an |che |ci a|vea |vòl|ti,
#
# Syllabifier input:       Tre passi ci facea il fiume lontani;
# Syllabifier output:      |Tre |pas|si |ci |fa|cea |il |fiu|me |lon|ta|ni;
# Correct syllabification: |Tre |pas|si |ci |fa|cea il |fiu|me |lon|ta|ni;
#
# Syllabifier input:       dov’ Eteòcle col fratel fu miso?».
# Syllabifier output:      |do|v’ E|teò|cle |col |fra|tel |fu |mi|so?».
# Correct syllabification: |do|v’ E|te|ò|cle |col |fra|tel |fu |mi|so?».
#
# Syllabifier input:       pensa che Pietro e Paulo, che moriro
# Syllabifier output:      |pen|sa |che |Pie|tro e |Pa|u|lo, |che |mo|ri|ro
# Correct syllabification: |pen|sa |che |Pie|tro e |Pau|lo, |che |mo|ri|ro
#
# Syllabifier input:       di Iosüè in su la Terra Santa,
# Syllabifier output:      |di |Io|sü|è in |su |la |Ter|ra |San|ta,
# Correct syllabification: |di |Io|sü|è |in |su |la |Ter|ra |San|ta,
#
# Syllabifier input:       pensa chi era, e la cagion che ’l mosse,
# Syllabifier output:      |pen|sa |chi e|ra, e |la |ca|gion |che ’l |mos|se,
# Correct syllabification: |pen|sa |chi |e|ra, e |la |ca|gion |che ’l |mos|se,
#
# Syllabifier input:       e vedra’ il corrègger che argomenta
# Syllabifier output:      |e |ve|dra’ |il |cor|règ|ger |che |ar|go|men|ta
# Correct syllabification: |e |ve|dra’ |il |cor|règ|ger |che ar|go|men|ta
#
# Syllabifier input:       che d’acqua fredda Indo o Etïopo.
# Syllabifier output:      |che |d’ ac|qua |fred|da In|do o |E|tï|o|po.
# Correct syllabification: |che |d’ ac|qua |fred|da |In|do o |E|tï|o|po.
#
# Syllabifier input:       Infin là sù la vide il patriarca
# Syllabifier output:      |In|fin |là |sù |la |vi|de il |pa|triar|ca
# Correct syllabification: |In|fin |là |sù |la |vi|de il |pa|tri|ar|ca
#
# Syllabifier input:       E ’l frate: «Io udi’ già dire a Bologna
# Syllabifier output:      |E ’l |fra|te:« |Io |u|di’ |già |di|re a |Bo|lo|gna
# Correct syllabification: |E ’l |fra|te:« Io |u|di’ |già |di|re a |Bo|lo|gna
#
# Syllabifier input:       avean le luci mie sì inebrïate,
# Syllabifier output:      |a|vean |le |lu|ci |mie |sì |i|ne|brï|a|te,
# Correct syllabification: |a|vean |le |lu|ci |mie |sì i|ne|brï|a|te,
#
# Syllabifier input:       si vider mäi in alcun tanto crude,
# Syllabifier output:      |si |vi|der |mäi |in |al|cun |tan|to |cru|de,
# Correct syllabification: |si |vi|der |mä|i in |al|cun |tan|to |cru|de,
#
# Syllabifier input:       lo sfavillar de l’amor che lì era
# Syllabifier output:      |lo |sfa|vil|lar |de |l’ a|mor |che |lì e|ra
# Correct syllabification: |lo |sfa|vil|lar |de |l’ a|mor |che |lì |e|ra
#
# Syllabifier input:       Di quel che fé col baiulo seguente,
# Syllabifier output:      |Di |quel |che |fé |col |ba|iu|lo |se|guen|te,
# Correct syllabification: |Di |quel |che |fé |col |bai|u|lo |se|guen|te,
#
# Syllabifier input:       così intrammo noi per la callaia,
# Syllabifier output:      |co|sì in|tram|mo |noi |per |la |cal|la|ia,
# Correct syllabification: |co|sì |in|tram|mo |noi |per |la |cal|laia,
#
# Syllabifier input:       che dovria l’uom tener dentro a sua meta.
# Syllabifier output:      |che |dov|ria |l’ uom |te|ner |den|tro a |sua |me|ta.
# Correct syllabification: |che |do|vria |l’ uom |te|ner |den|tro a |sua |me|ta.
#
# Syllabifier input:       Or perché in circuito tutto quanto
# Syllabifier output:      |Or |per|ché in |cir|cu|i|to |tut|to |quan|to
# Correct syllabification: |Or |per|ché |in |cir|cui|to |tut|to |quan|to
#
# Syllabifier input:       che a’ miei propinqui tu ben mi rinfami.
# Syllabifier output:      |che |a’ |miei |pro|pin|qui |tu |ben |mi |rin|fa|mi.
# Correct syllabification: |che a’ |miei |pro|pin|qui |tu |ben |mi |rin|fa|mi.
#
# Syllabifier input:       e l’ali d’oro, e l’altro tanto bianco,
# Syllabifier output:      |e |l’ a|li |d’ o|ro, e |l’ al|tro |tan|tian|co,
# Correct syllabification: |e |l’ a|li |d’ o|ro, e |l’ al|tro |tan|to |bian|co,
#
# Syllabifier input:       con l’ali aperte li giacea un draco;
# Syllabifier output:      |con |l’ a|li a|per|te |li |gia|cea un |dra|co;
# Correct syllabification: |con |l’ a|li a|per|te |li |gia|cea |un |dra|co;
#
# Syllabifier input:       lo dolce ber che mai non m’avria sazio;
# Syllabifier output:      |lo |dol|ce |ber |che |mai |non |m’ av|ria |sa|zio;
# Correct syllabification: |lo |dol|ce |ber |che |mai |non |m’ a|vria |sa|zio;
#
# Syllabifier input:       Poi disse: «Più pensava Maria onde
# Syllabifier output:      |Poi |dis|se:« |Più |pen|sa|va |Ma|ria on|de
# Correct syllabification: |Poi |dis|se:« |Più |pen|sa|va |Ma|ria |on|de
#
# Syllabifier input:       che quella di colui che li è davante;
# Syllabifier output:      |che |quel|la |di |co|lui |che |li |è |da|van|te;
# Correct syllabification: |che |quel|la |di |co|lui |che |li è |da|van|te;

# %%
print_ratio(test_verses_nosyll, test_set_mistakes)
# Out:
# Number of correctly syllabified verses: 1384/1424 (97.2%)

# %% [markdown]
# ## Validation Set

# %%
#write_predictions(val_verses_nosyll, val_verses_syll, 'validation_set_prediction.txt')

# %%
val_set_predictions = store_predictions('validation_set_prediction.txt')

# %%
val_set_mistakes = print_mistakes(val_verses_nosyll, val_set_predictions, val_verses_syll)
# Out:
# Syllabifier input:       e che s’incontran con sì aspre lingue,
# Syllabifier output:      |e |che |s’ in|con|tran |con |sì |a|spre |lin|gue,
# Correct syllabification: |e |che |s’ in|con|tran |con |sì |as|pre |lin|gue,
#
# Syllabifier input:       volgendom’ io con li etterni Gemelli,
# Syllabifier output:      |vol|gen|dom’ |io |con |li et|ter|ni |Ge|mel|li,
# Correct syllabification: |vol|gen|do|m’ io |con |li et|ter|ni |Ge|mel|li,
#
# Syllabifier input:       «Osanna, sanctus Deus sabaòth,
# Syllabifier output:      « |O|san|na, |sanc|cus |De|us |sa|ba|òth,
# Correct syllabification: « |O|san|na, |sanc|tus |De|us |sa|ba|òth,
#
# Syllabifier input:       a le curule Sizii e Arrigucci.
# Syllabifier output:      |a |le |cu|ru|le |Si|ziii e |Ar|ri|guc|ci.
# Correct syllabification: |a |le |cu|ru|le |Si|zii |e Ar|ri|guc|ci.
#
# Syllabifier input:       l’onor d’Agobbio e l’onor di quell’ arte
# Syllabifier output:      |l’ o|nor |d’ A|gob|bio e |l’ o|n |di |quel|l’ ar|te
# Correct syllabification: |l’ o|nor |d’ A|gob|bio e |l’ o|nor |di |quel|l’ ar|te
#
# Syllabifier input:       che ’l tien legato, o anima confusa,
# Syllabifier output:      |che ’l |tien |le|ga|to, o |o |a|ni|ma |con|fu|sa,
# Correct syllabification: |che ’l |tien |le|ga|to, o |a|ni|ma |con|fu|sa,
#
# Syllabifier input:       che crede e non, dicendo «Ella è . . . non è . . . »,
# Syllabifier output:      |che |cre|de e |non, |di|cen|do« El|la è... |non |è....
# Correct syllabification: |che |cre|de e |non, |di|cen|do« El|la è... |non |è...»,
#
# Syllabifier input:       scias quod ego fui successor Petri.
# Syllabifier output:      |scias |quod |e|go |fui |suc|ces|sor |Pe|tri.
# Correct syllabification: |sci|as |quod |e|go |fui |suc|ces|sor |Pe|tri.
#
# Syllabifier input:       cominciò el, «se non . . . Tal ne s’offerse.
# Syllabifier output:      |co|min|ciò |el,« |se |non.. |Tal |ne |s’ of|fer|se.
# Correct syllabification: |co|min|ciò |el,« |se |non... |Tal |ne |s’ of|fer|se.
#
# Syllabifier input:       l’aiuta sì ch’i’ ne sia consolata.
# Syllabifier output:      |l’ ai|ta |sì |ch’ i’ |ne |sia |con|so|la|ta.
# Correct syllabification: |l’ a|iu|ta |sì |ch’ i’ |ne |sia |con|so|la|ta.
#
# Syllabifier input:       ricominciò il cortese portinaio:
# Syllabifier output:      |ri|co|min|ciò |il |cor|te|se |por|ti|naio:
# Correct syllabification: |ri|co|min|ciò il |cor|te|se |por|ti|na|io:
#
# Syllabifier input:       la revestita voce alleluiando,
# Syllabifier output:      |la |re|ve|sti|ta |vo|ce al|le|lu|ian|do,
# Correct syllabification: |la |re|ve|sti|ta |vo|ce al|le|lui|an|do,
#
# Syllabifier input:       S’ïo avessi le rime aspre e chiocce,
# Syllabifier output:      |S’ ï|o a|ves|si |le |ri|me a|spre e |chioc|ce,
# Correct syllabification: |S’ ï|o a|ves|si |le |ri|me |as|pre e |chioc|ce,
#
# Syllabifier input:       Certo tra esso e ’l gaudio mi facea
# Syllabifier output:      |Cer|to |tra es|so e ’l |gau|dio |mi |fa|cea
# Correct syllabification: |Cer|to |tra |es|so e ’l |gau|dio |mi |fa|cea
#
# Syllabifier input:       e Galli e quei ch’arrossan per lo staio.
# Syllabifier output:      |e |Gal|li e |quei |ch’ ar|ros|san |per |lo |sta|io.
# Correct syllabification: |e |Gal|li e |quei |ch’ ar|ros|san |per |lo |staio.
#
# Syllabifier input:       volsesi in su i vermigli e in su i gialli
# Syllabifier output:      |vol|se|si in |su i |ver|mi|gli e in |su i |gial|li
# Correct syllabification: |vol|se|si in |su i |ver|mi|gli e in |su |i |gial|li
#
# Syllabifier input:       allor che ben conobbe il galeotto,
# Syllabifier output:      |al|lor |che |ben |co|nob|be il |ga|leot|to,
# Correct syllabification: |al|lor |che |ben |co|nob|be il |ga|le|ot|to,
#
# Syllabifier input:       «O fronda mia in che io compiacemmi
# Syllabifier output:      « |O |fron|da |mia |in |che |io |com|pia|cem|mi
# Correct syllabification: « |O |fron|da |mia |in |che io |com|pi|a|cem|mi
#
# Syllabifier input:       ché se chelidri, iaculi e faree
# Syllabifier output:      |ché |se |che|li|dri, |ia|cu|li e |fa|re
# Correct syllabification: |ché |se |che|li|dri, |ia|cu|li e |fa|ree
#
# Syllabifier input:       con archi e asticciuole prima elette;
# Syllabifier output:      |con |ar|chi e |a|stic|ciuo|le |pri|ma e|let|te;
# Correct syllabification: |con |ar|chi e |as|tic|ciuo|le |pri|ma e|let|te;
#
# Syllabifier input:       ma già volgeva il mio disio e ’l velle,
# Syllabifier output:      |ma |già |vol|ge|va il |mio |di|sio e ’l |vel|le,
# Correct syllabification: |ma |già |vol|ge|va il |mio |di|sio |e ’l |vel|le,
#
# Syllabifier input:       venimmo ove quell’ anime ad una
# Syllabifier output:      |ve|nim|mo o|ve |quel|l’ a|ni|me ad |u|na
# Correct syllabification: |ve|nim|mo o|ve |quel|l’ a|ni|me |ad |u|na
#
# Syllabifier input:       Pontì e Normandia prese e Guascogna.
# Syllabifier output:      |Pon|tì e |Nor|man|dia |pre|se e |Gua|sco|gna.
# Correct syllabification: |Pon|tì |e |Nor|man|dia |pre|se e |Gua|sco|gna.
#
# Syllabifier input:       qua dentro è ’l secondo Federico
# Syllabifier output:      |qua |den|tro è ’l |se|con|do |Fe|de|ri|co
# Correct syllabification: |qua |den|tro |è ’l |se|con|do |Fe|de|ri|co
#
# Syllabifier input:       dico nel cielo, io me ne gloriai.
# Syllabifier output:      |di|co |nel |cie|lo, io |me |ne |glo|riai.
# Correct syllabification: |di|co |nel |cie|lo, |io |me |ne |glo|riai.
#
# Syllabifier input:       qu’ieu no me puesc ni voill a vos cobrire.
# Syllabifier output:      |qu’ ieu |no |me |puesc |ni |voil |a |vos |co|bri|re.
# Correct syllabification: |qu’ ieu |no |me |puesc |ni |voill |a |vos |co|bri|re.
#
# Syllabifier input:       tutto, qual che si sia, il mio ingegno,
# Syllabifier output:      |tut|to, |qual |che |si |sia, il |mio |in|ge|gno,
# Correct syllabification: |tut|to, |qual |che |si |sia, |il |mio |in|ge|gno,

# %%
print_ratio(val_verses_nosyll, val_set_mistakes)
# Out:
# Number of correctly syllabified verses: 2819/2846 (99.1%)

# %% [markdown]
# ## Training Set

# %%
#write_predictions(train_verses_nosyll, train_verses_syll, 'training_set_prediction.txt')

# %%
train_set_predictions = store_predictions('training_set_prediction.txt')

# %%
train_set_mistakes = print_mistakes(train_verses_nosyll, train_set_predictions, train_verses_syll)
# Out:
# Syllabifier input:       legge, moneta, officio e costume
# Syllabifier output:      |leg|ge, |mo|ne|ta, of|fi|cio e |co|stu|me
# Correct syllabification: |leg|ge, |mo|ne|ta, of|fi|cio |e |co|stu|me
#
# Syllabifier input:       di Nostra Donna in sul lito adriano.
# Syllabifier output:      |di |No|stra |Don|na in |sul |li|to a|dria|no.
# Correct syllabification: |di |No|stra |Don|na in |sul |li|to a|dri|a|no.
#
# Syllabifier input:       nel prossimo si danno, e nel suo avere
# Syllabifier output:      |nel |pros|si|mo |si |dan|no, e |nel |suo |a|ve|re
# Correct syllabification: |nel |pros|si|mo |si |dan|no, e |nel |suo a|ve|re
#
# Syllabifier input:       Già eran sovra noi tanto levati
# Syllabifier output:      |Già |e|ran |sov|ra |noi |tan|to |le|va|ti
# Correct syllabification: |Già |e|ran |so|vra |noi |tan|to |le|va|ti
#
# Syllabifier input:       «O Virgilio, Virgilio, chi è questa?»,
# Syllabifier output:      « |O |Vir|gi|lio, |Vir|gi|lio, |chi è |que|sta?»,
# Correct syllabification: « |O |Vir|gi|lio, |Vir|gi|lio, |chi |è |que|sta?»,
#
# Syllabifier input:       che morì per la bella Deianira,
# Syllabifier output:      |che |mo|rì |per |la |bel|la |De|i|a|ni|ra,
# Correct syllabification: |che |mo|rì |per |la |bel|la |Dei|a|ni|ra,
#
# Syllabifier input:       s’io m’intuassi, come tu t’inmii».
# Syllabifier output:      |s’ io |m’ in|tu|as|si, |co|me |tu |t’ in|miii».
# Correct syllabification: |s’ io |m’ in|tu|as|si, |co|me |tu |t’ in|mii».
#
# Syllabifier input:       Ma io veggi’ or la tua mente ristretta
# Syllabifier output:      |Ma |io |veg|gi’ or |la |tua |men|te |ri|stret|ta
# Correct syllabification: |Ma io |veg|gi’ |or |la |tua |men|te |ri|stret|ta
#
# Syllabifier input:       menava ïo li occhi per li gradi,
# Syllabifier output:      |me|na|va ï|o |li oc|chi |per |li |gra|di,
# Correct syllabification: |me|na|va |ï|o |li oc|chi |per |li |gra|di,
#
# Syllabifier input:       a tal da cui la nota non è intesa,
# Syllabifier output:      |a |tal |da |cui |la |no|ta |non |è |in|te|sa,
# Correct syllabification: |a |tal |da |cui |la |no|ta |non |è in|te|sa,
#
# Syllabifier input:       Io non Enëa, io non Paulo sono;
# Syllabifier output:      |Io |non |E|në|a, |io |non |Pa|u|lo |so|no;
# Correct syllabification: |Io |non |E|në|a, |io |non |Pau|lo |so|no;
#
# Syllabifier input:       rimontò ’l duca mio e trasse mee;
# Syllabifier output:      |ri|mon|tò ’l |du|ca |mio |e |tras|se |me;
# Correct syllabification: |ri|mon|tò ’l |du|ca |mio |e |tras|se |mee;
#
# Syllabifier input:       pon giù il seme del piangere e ascolta:
# Syllabifier output:      |pon |giù |il |se|me |del |pian|ge|re e |a|scol|ta:
# Correct syllabification: |pon |giù |il |se|me |del |pian|ge|re e a|scol|ta:
#
# Syllabifier input:       per che no i volle Gedeon compagni,
# Syllabifier output:      |per |che |no i |vol|le |Ge|deon |com|pa|gni,
# Correct syllabification: |per |che |no i |vol|le |Ge|de|on |com|pa|gni,
#
# Syllabifier input:       ma sapïenza, amore e virtute,
# Syllabifier output:      |ma |sa|pï|en|za, a|mo|re e |vir|tu|te,
# Correct syllabification: |ma |sa|pï|en|za, a|mo|re |e |vir|tu|te,
#
# Syllabifier input:       ben la ruina, e diedemi di piglio.
# Syllabifier output:      |ben |la |rui|na, e |die|de|mi |di |pi|glio.
# Correct syllabification: |ben |la |ru|i|na, e |die|de|mi |di |pi|glio.
#
# Syllabifier input:       tra ’ quai conobbi Ettòr ed Enea,
# Syllabifier output:      |tra ’ |quai |co|nob|bi |Et|tòr |ed |E|E|nea,
# Correct syllabification: |tra ’ |quai |co|nob|bi |Et|tòr |ed |E|nea,
#
# Syllabifier input:       omai la navicella del mio ingegno,
# Syllabifier output:      |o|mai |la |na|vi|cel|la |del |mio |in|ge|gno,
# Correct syllabification: |o|mai |la |na|vi|cel|la |del |mio in|ge|gno,
#
# Syllabifier input:       Vedeva Troia in cenere e in caverne;
# Syllabifier output:      |Ve|de|va |Troia |in |ce|ne|re e |in |ca|ver|ne;
# Correct syllabification: |Ve|de|va |Tro|ia in |ce|ne|re e in |ca|ver|ne;
#
# Syllabifier input:       e or s’accoscia e ora è in piedi stante.
# Syllabifier output:      |e |or |s’ ac|co|scia e |o|ra è |in |pie|di |stan|te.
# Correct syllabification: |e or |s’ ac|co|scia e |o|ra è |in |pie|di |stan|te.
#
# Syllabifier input:       e quella parte onde prima è preso
# Syllabifier output:      |e |quel|la |par|te on|de |pri|ma è |pre|so
# Correct syllabification: |e |quel|la |par|te on|de |pri|ma |è |pre|so
#
# Syllabifier input:       chi ei si fosser e onde venner quivi,
# Syllabifier output:      |chi |ei |si |fos|ser |e |on|de |ven|ner |qui|vi,
# Correct syllabification: |chi ei |si |fos|ser |e |on|de |ven|ner |qui|vi,
#
# Syllabifier input:       dal suo principio ch’è in questo troncone.
# Syllabifier output:      |dal |suo |prin|ci|pio |ch’ è |in |que|sto |tron|co|ne.
# Correct syllabification: |dal |suo |prin|ci|pio |ch’ è in |que|sto |tron|co|ne.
#
# Syllabifier input:       di tutta l’animal perfezïone;
# Syllabifier output:      |di |tut|ta |l’ a|ni|mal |per|fï|o|ne;
# Correct syllabification: |di |tut|ta |l’ a|ni|mal |per|fe|zï|o|ne;
#
# Syllabifier input:       e cu’ io vidi su in terra latina,
# Syllabifier output:      |e |cu’ |io |vi|di |su |in |ter|ra |la|ti|na,
# Correct syllabification: |e |cu’ |io |vi|di |su in |ter|ra |la|ti|na,
#
# Syllabifier input:       dinanzi a li occhi mi si fu offerto
# Syllabifier output:      |di|nan|zi a |li oc|chi |mi |si |fu of|fer|to
# Correct syllabification: |di|nan|zi a |li oc|chi |mi |si |fu |of|fer|to
#
# Syllabifier input:       sovr’ altrui sangue in natural vasello.
# Syllabifier output:      |sov|r’ al|trui |san|gue |in |na|tu|ral |va|sel|lo.
# Correct syllabification: |sov|r’ al|trui |san|gue in |na|tu|ral |va|sel|lo.
#
# Syllabifier input:       d’infanti e di femmine e di viri.
# Syllabifier output:      |d’ in|fan|ti e |di |fem|mi|ne e |di |vi|ri.
# Correct syllabification: |d’ in|fan|ti |e |di |fem|mi|ne e |di |vi|ri.
#
# Syllabifier input:       cortesia e valor dì se dimora
# Syllabifier output:      |cor|te|sia e |va|lor |dì |se |di|mo|ra
# Correct syllabification: |cor|te|sia |e |va|lor |dì |se |di|mo|ra
#
# Syllabifier input:       El disse a me: «Tosto verrà di sovra
# Syllabifier output:      |El |dis|se a |me:« |To|sto |ver|rà |di |sov|ra
# Correct syllabification: |El |dis|se a |me:« |To|sto |ver|rà |di |so|vra
#
# Syllabifier input:       guardando il foco e imaginando forte
# Syllabifier output:      |guar|dan|do il |fo|co e |i|ma|gi|nan|do |for|te
# Correct syllabification: |guar|dan|do il |fo|co e i|ma|gi|nan|do |for|te
#
# Syllabifier input:       fedir torneamenti e correr giostra;
# Syllabifier output:      |fe|dir |tor|nea|men|ti e |cor|rer |gio|stra;
# Correct syllabification: |fe|dir |tor|ne|a|men|ti e |cor|rer |gio|stra;
#
# Syllabifier input:       Libicocco vegn’ oltre e Draghignazzo,
# Syllabifier output:      |Li|bi|coc|co |ve|gn’ ol|tre e |Dra|ghi|gnaz|zo,
# Correct syllabification: |Li|bi|coc|co |veg|n’ ol|tre e |Dra|ghi|gnaz|zo,
#
# Syllabifier input:       tant’ era pien di sonno a quel punto
# Syllabifier output:      |tan|t’ e|ra |pien |di |son|no a |quel |pun|to
# Correct syllabification: |tan|t’ e|ra |pien |di |son|no |a |quel |pun|to
#
# Syllabifier input:       e queste cose pur furon creature;
# Syllabifier output:      |e |que|ste |co|se |pur |fu|ron |cre|a|tu|re;
# Correct syllabification: |e |que|ste |co|se |pur |fu|ron |crea|tu|re;
#
# Syllabifier input:       non disdegnò di farsi sua fattura.
# Syllabifier output:      |non |di|sde|gnò |di |far|si |sua |fat|tu|ra.
# Correct syllabification: |non |di|sdeg|nò |di |far|si |sua |fat|tu|ra.
#
# Syllabifier input:       per lei, tanto che a Dio si sodisfaccia,
# Syllabifier output:      |per |lei, |tan|to |che |a |Dio |si |so|di|sfac|cia,
# Correct syllabification: |per |lei, |tan|to |che a |Dio |si |so|di|sfac|cia,
#
# Syllabifier input:       era onorata, essa e suoi consorti:
# Syllabifier output:      |e|ra o|no|ra|ta, es|sa e |suoi |con|sor|ti:
# Correct syllabification: |e|ra o|no|ra|ta, es|sa |e |suoi |con|sor|ti:
#
# Syllabifier input:       o con men che non dee corre nel bene,
# Syllabifier output:      |o |con |men |che |non |de |cor|re |nel |be|ne,
# Correct syllabification: |o |con |men |che |non |dee |cor|re |nel |be|ne,
#
# Syllabifier input:       discese, avria mestier di tal milizia
# Syllabifier output:      |di|sce|se, av|ria |me|stier |di |tal |mi|li|zia
# Correct syllabification: |di|sce|se, a|vria |me|stier |di |tal |mi|li|zia
#
# Syllabifier input:       il quale e il quanto de la viva stella
# Syllabifier output:      |il |qua|le e |il |quan|to |de |la |vi|va |stel|la
# Correct syllabification: |il |qua|le e il |quan|to |de |la |vi|va |stel|la
#
# Syllabifier input:       che al giudicio divin passion comporta?
# Syllabifier output:      |che |al |giu|di|cio |di|vin |pas|sion |com|por|ta?
# Correct syllabification: |che al |giu|di|cio |di|vin |pas|sion |com|por|ta?
#
# Syllabifier input:       Io stava sovra ’l ponte a veder surto,
# Syllabifier output:      |Io |sta|va |sov|ra ’l |pon|te a |ve|der |sur|to,
# Correct syllabification: |Io |sta|va |so|vra ’l |pon|te a |ve|der |sur|to,
#
# Syllabifier input:       ma pari in atto e onesto e sodo.
# Syllabifier output:      |ma |pa|ri in |at|to e |o|ne|sto e |so|do.
# Correct syllabification: |ma |pa|ri in |at|to e |o|ne|sto |e |so|do.
#
# Syllabifier input:       e dentro a quei che più innanzi appariro
# Syllabifier output:      |e |den|tro a |quei |che |più |in|nan|zi ap|pa|ri|ro
# Correct syllabification: |e |den|tro a |quei |che |più in|nan|zi ap|pa|ri|ro
#
# Syllabifier input:       d’una di lor ch’avea tre occhi in testa.
# Syllabifier output:      |d’ u|na |di |lor |ch’ a|vea |tre oc|chi in |te|sta.
# Correct syllabification: |d’ u|na |di |lor |ch’ a|vea |tre |oc|chi in |te|sta.
#
# Syllabifier input:       ché a tutti un fil di ferro i cigli fóra
# Syllabifier output:      |ché |a |tut|ti un |fil |di |fer|ro i |ci|gli |fó|ra
# Correct syllabification: |ché a |tut|ti un |fil |di |fer|ro i |ci|gli |fó|ra
#
# Syllabifier input:       trassimi sovra quella creatura
# Syllabifier output:      |tras|si|mi |sov|ra |quel|la |cre|a|tu|ra
# Correct syllabification: |tras|si|mi |so|vra |quel|la |cre|a|tu|ra
#
# Syllabifier input:       Onde, se ’l mio disir dee aver fine
# Syllabifier output:      |On|de, |se ’l |mio |di|sir |de |a|ver |fi|ne
# Correct syllabification: |On|de, |se ’l |mio |di|sir |dee |a|ver |fi|ne
#
# Syllabifier input:       Tu non se’ in terra, sì come tu credi;
# Syllabifier output:      |Tu |non |se’ |in |ter|ra, |sì |co|me |tu |cre|di;
# Correct syllabification: |Tu |non |se’ in |ter|ra, |sì |co|me |tu |cre|di;
#
# Syllabifier input:       su per lo suol che d’ogne parte auliva.
# Syllabifier output:      |su |per |lo |suol |che |d’ o|gne |par|te a|u|li|va.
# Correct syllabification: |su |per |lo |suol |che |d’ o|gne |par|te au|li|va.
#
# Syllabifier input:       s’era allungata, unì a sé in persona
# Syllabifier output:      |s’ e|ra al|lun|ga|ta, u|nì |a |sé |in |per|so|na
# Correct syllabification: |s’ e|ra al|lun|ga|ta, u|nì |a |sé in |per|so|na
#
# Syllabifier input:       e in quella forma ch’è in lui suggella
# Syllabifier output:      |e |in |quel|la |for|ma |ch’ è |in |lui |sug|gel|la
# Correct syllabification: |e in |quel|la |for|ma |ch’ è |in |lui |sug|gel|la
#
# Syllabifier input:       che li assegnò sette e cinque per diece,
# Syllabifier output:      |che |li as|se|gnò |set|te e |cin|que |per |die|ce,
# Correct syllabification: |che |li as|seg|nò |set|te e |cin|que |per |die|ce,
#
# Syllabifier input:       come fa donna che in parturir sia;
# Syllabifier output:      |co|me |fa |don|na |che |in |par|tu|rir |sia;
# Correct syllabification: |co|me |fa |don|na |che in |par|tu|rir |sia;
#
# Syllabifier input:       che i tre a’ tre pugnar per lui ancora.
# Syllabifier output:      |che i |tre a’ |tre |pu|gnar |per |lui |an|co|ra.
# Correct syllabification: |che i |tre |a’ |tre |pu|gnar |per |lui |an|co|ra.
#
# Syllabifier input:       che averle dentro e sostener lo puzzo
# Syllabifier output:      |che |a|ver|le |den|tro e |so|ste|ner |lo |puz|zo
# Correct syllabification: |che a|ver|le |den|tro e |so|ste|ner |lo |puz|zo
#
# Syllabifier input:       che quel che vole Iddio, e noi volemo».
# Syllabifier output:      |che |quel |che |vo|le Id|dio, e |noi |vo|le|mo».
# Correct syllabification: |che |quel |che |vo|le Id|dio, |e |noi |vo|le|mo».
#
# Syllabifier input:       rispuos’ io lui, «mi smarri’ in una valle,
# Syllabifier output:      |ri|spuo|s’ io |lui,« |mi |smar|ri’ |in |u|na |val|le,
# Correct syllabification: |ri|spuo|s’ io |lui,« |mi smar|ri’ |in |u|na |val|le,
#
# Syllabifier input:       ch’a la prim’ arte degnò porre mano.
# Syllabifier output:      |ch’ a |la |pri|m’ ar|te |de|gnò |por|re |ma|no.
# Correct syllabification: |ch’ a |la |pri|m’ ar|te |deg|nò |por|re |ma|no.
#
# Syllabifier input:       le lagrime tra essi e riserrolli.
# Syllabifier output:      |le |la|gri|me |tra es|si e |ri|ser|rol|li.
# Correct syllabification: |le |la|gri|me |tra |es|si e |ri|ser|rol|li.
#
# Syllabifier input:       che a pena poscia li avrei ritenuti;
# Syllabifier output:      |che |a |pe|na |po|scia |li av|rei |ri|te|nu|ti;
# Correct syllabification: |che a |pe|na |po|scia |li av|rei |ri|te|nu|ti;
#
# Syllabifier input:       che nulla volontà è di più ausa,
# Syllabifier output:      |che |nul|la |vo|lon|tà |è |di |più |a|u|sa,
# Correct syllabification: |che |nul|la |vo|lon|tà |è |di |più a|u|sa,
#
# Syllabifier input:       e avea in atto impressa esta favella
# Syllabifier output:      |e |a|vea |in |at|to im|pres|sa e|sta |fa|vel|la
# Correct syllabification: |e a|vea |in |at|to im|pres|sa e|sta |fa|vel|la
#
# Syllabifier input:       Io cominciai: «O frati, i vostri mali . . . »;
# Syllabifier output:      |Io |co|min|ciai:« |O |fra|ti, i |vo|stri |ma|li..
# Correct syllabification: |Io |co|min|ciai:« |O |fra|ti, i |vo|stri |ma|li...»;
#
# Syllabifier input:       così tutta la gente che lì era,
# Syllabifier output:      |co|sì |tut|ta |la |gen|te |che |lì e|ra,
# Correct syllabification: |co|sì |tut|ta |la |gen|te |che |lì |e|ra,
#
# Syllabifier input:       “Glorïa in excelsis” tutti “Deo”
# Syllabifier output:      “ |Glo|rï|a in |ex|cel|sis” |tut|ti“ |Deo”
# Correct syllabification: “ |Glo|rï|a |in |ex|cel|sis” |tut|ti“ |Deo”
#
# Syllabifier input:       ma per sé stessa pur fu ella sbandita
# Syllabifier output:      |ma |per |sé |stes|sa |pur |fu |el|la |sban|di|ta
# Correct syllabification: |ma |per |sé |stes|sa |pur |fu el|la |sban|di|ta
#
# Syllabifier input:       più che in altra convien che si mova
# Syllabifier output:      |più |che in |al|tra |con|vien |che |si |mo|va
# Correct syllabification: |più |che |in |al|tra |con|vien |che |si |mo|va
#
# Syllabifier input:       si stava in pace, sobria e pudica.
# Syllabifier output:      |si |sta|va in |pa|ce, |so|bria e |pu|di|ca.
# Correct syllabification: |si |sta|va in |pa|ce, |so|bria |e |pu|di|ca.
#
# Syllabifier input:       sì che ’n poc’ ora avria l’orecchia offesa.
# Syllabifier output:      |sì |che ’n |po|c’ o|ra av|ria |l’ o|rec|chia of|fe|sa.
# Correct syllabification: |sì |che ’n |po|c’ o|ra a|vria |l’ o|rec|chia of|fe|sa.
#
# Syllabifier input:       E già il poeta innanzi mi saliva,
# Syllabifier output:      |E |già |il |po|e|ta in|nan|zi |mi |sa|li|va,
# Correct syllabification: |E |già il |po|e|ta in|nan|zi |mi |sa|li|va,
#
# Syllabifier input:       giurato avria poco lontano aspetto
# Syllabifier output:      |giu|ra|to av|ria |po|co |lon|ta|no a|spet|to
# Correct syllabification: |giu|ra|to a|vria |po|co |lon|ta|no a|spet|to
#
# Syllabifier input:       «Mantüa . . . », e l’ombra, tutta in sé romita,
# Syllabifier output:      « |Man|tü|a....», e |l’ om|bra, |tut|ta in |sé |ro|mi|ta,
# Correct syllabification: « |Man|tü|a...», e |l’ om|bra, |tut|ta in |sé |ro|mi|ta,
#
# Syllabifier input:       esso litare stato accetto e fausto;
# Syllabifier output:      |es|so |li|ta|re |sta|to ac|cet|to e |fa|u|sto;
# Correct syllabification: |es|so |li|ta|re |sta|to ac|cet|to e |fau|sto;
#
# Syllabifier input:       ricompie forse negligenza e indugio
# Syllabifier output:      |ri|com|pie |for|se |ne|gli|gen|za e |in|du|gio
# Correct syllabification: |ri|com|pie |for|se |ne|gli|gen|za e in|du|gio
#
# Syllabifier input:       se orazïone in prima non m’aita
# Syllabifier output:      |se |o|ra|zï|o|ne in |pri|ma |non |m’ a|i|ta
# Correct syllabification: |se o|ra|zï|o|ne in |pri|ma |non |m’ a|i|ta
#
# Syllabifier input:       nuvole spesse non paion né rade,
# Syllabifier output:      |nu|vo|le |spes|se |non |pa|ion |né |ra|de,
# Correct syllabification: |nu|vo|le |spes|se |non |pai|on |né |ra|de,
#
# Syllabifier input:       mi disse: «Non sai tu che tu se’ in cielo?
# Syllabifier output:      |mi |dis|se:« |Non |sai |tu |che |tu |se’ |in |cie|lo?
# Correct syllabification: |mi |dis|se:« |Non |sai |tu |che |tu |se’ in |cie|lo?
#
# Syllabifier input:       «Qui li trovai—e poi volta non dierno—»,
# Syllabifier output:      « |Qui |li |tro|vai— |poi |vol|ta |non |dier|no—»,
# Correct syllabification: « |Qui |li |tro|vai— |e |poi |vol|ta |non |dier|no—»,
#
# Syllabifier input:       quivi sto io con quei che le tre sante
# Syllabifier output:      |qui|vi |sto io |con |quei |che |le |tre |san|te
# Correct syllabification: |qui|vi |sto |io |con |quei |che |le |tre |san|te
#
# Syllabifier input:       ché Branca Doria non morì unquanche,
# Syllabifier output:      |ché |Bran|ca |Do|ria |non |mo|rì un|quan|che,
# Correct syllabification: |ché |Bran|ca |Do|ria |non |mo|rì |un|quan|che,
#
# Syllabifier input:       Buggea siede e la terra ond’ io fui,
# Syllabifier output:      |Bug|gea |sie|de e |la |ter|ra on|d’ io |fui,
# Correct syllabification: |Bug|ge|a |sie|de e |la |ter|ra on|d’ io |fui,
#
# Syllabifier input:       nel qual non si dee creder che s’invii
# Syllabifier output:      |nel |qual |non |si |de |cre|der |che |s’ in|viii
# Correct syllabification: |nel |qual |non |si |dee |cre|der |che |s’ in|vii
#
# Syllabifier input:       rimasa è per danno de le carte.
# Syllabifier output:      |ri|ma|sa è |per |dan|no |de |le |car|te.
# Correct syllabification: |ri|ma|sa |è |per |dan|no |de |le |car|te.
#
# Syllabifier input:       che riceve da Euro maggior briga,
# Syllabifier output:      |che |ri|ce|ve |da E|u|ro |mag|gior |bri|ga,
# Correct syllabification: |che |ri|ce|ve |da |Eu|ro |mag|gior |bri|ga,
#
# Syllabifier input:       i’ dico di Traiano imperadore;
# Syllabifier output:      |i’ |di|co |di |Tra|ia|no im|pe|ra|do|re;
# Correct syllabification: |i’ |di|co |di |Trai|a|no im|pe|ra|do|re;
#
# Syllabifier input:       rispondi a me che ’n sete e ’n foco ardo.
# Syllabifier output:      |ri|spon|di a |me |che ’n |se|te e ’n |fo|co ar|do.
# Correct syllabification: |ri|spon|di |a |me |che ’n |se|te e ’n |fo|co ar|do.
#
# Syllabifier input:       Lo rege per cui questo regno pausa
# Syllabifier output:      |Lo |re|ge |per |cui |que|sto |re|gno |pa|u|sa
# Correct syllabification: |Lo |re|ge |per |cui |que|sto |re|gno |pau|sa
#
# Syllabifier input:       peneia, quando alcun di sé asseta.
# Syllabifier output:      |pe|neia, |quan|do al|cun |di |sé |as|se|ta.
# Correct syllabification: |pe|ne|ia, |quan|do al|cun |di |sé |as|se|ta.
#
# Syllabifier input:       In essa gerarcia son l’altre dee:
# Syllabifier output:      |In |es|sa |ge|rar|cia |son |l’ al|tre |de:
# Correct syllabification: |In |es|sa |ge|rar|cia |son |l’ al|tre |dee:
#
# Syllabifier input:       del bello ovile ov’ io dormi’ agnello,
# Syllabifier output:      |del |bel|lo o|vi|le o|v’ io |dor|mi’ a|gnel|lo,
# Correct syllabification: |del |bel|lo o|vi|le o|v’ io |dor|mi’ |a|gnel|lo,
#
# Syllabifier input:       del dire e del tacer, si sta; ond’ io,
# Syllabifier output:      |del |di|re e |del |ta|cer, |si |sta; on|d’ io,
# Correct syllabification: |del |di|re e |del |ta|cer, |si |sta; |on|d’ io,

# %%
print_ratio(train_verses_nosyll, train_set_mistakes)
# Out:
# Number of correctly syllabified verses: 9870/9963 (99.1%)
